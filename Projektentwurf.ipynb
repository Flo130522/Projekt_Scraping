# %% [markdown]
# # Projekt - Supermarkt-Standortanalyse _(Dateiablage)_
# ## Daten einlesen
# ### Modulimport

# %%
import requests
import bs4
from bs4 import BeautifulSoup

# %%
url1 = 'https://www.offen.net/brandenburg-havel/supermarkt-index.html'
url2 = 'https://www.offen.net/brandenburg-havel/supermarkt-index-2.html'
url3 = 'https://www.offen.net/brandenburg-havel/supermarkt-index-3.html'

# %% [markdown]
# ### Marktinfos

# %%
response = requests.get(url1)
soup = BeautifulSoup(response.text, 'html.parser')

for link in soup.find_all()
# Out:
#   Cell In[2], line 4
#     for link in soup.find_all()
#                                ^
# SyntaxError: expected ':'

# %%
import requests
from bs4 import BeautifulSoup

# Liste der URLs der Supermarktseiten
urls = [
    'https://www.offen.net/brandenburg-havel/supermarkt-index.html',
    'https://www.offen.net/brandenburg-havel/supermarkt-index-2.html',
    'https://www.offen.net/brandenburg-havel/supermarkt-index-3.html'
]

# Erstelle eine leere Liste, um die Daten aller Supermärkte zu speichern
supermarkt_daten = []

# Schleife durch jede URL
for url in urls:
    # Holen der HTML-Seite
    response = requests.get(url)

    # Parsing der HTML-Seite
    soup = BeautifulSoup(response.text, 'html.parser')

    # Extrahiere die Supermarktinformationen aus der Seite
    supermarkt_info = soup.find_all('a', href=True, title=True)

    # Schleife durch die gefundenen Supermarktinformationen
    for info in supermarkt_info:
        filialname = info.strong.text
        adresse = info.find_all('div')
        strasse = adresse[0].text
        stadt = adresse[1].text

        # Speichere die Daten in einem Dictionary
        supermarkt = {
            'Filialname': filialname,
            'Straße': strasse,
            'Stadt': stadt
        }

        # Füge das Dictionary zur Liste hinzu
        supermarkt_daten.append(supermarkt)

supermarkt_daten
# Out:
# [{'Filialname': 'REWE',
#   'Straße': '\nNeuendorfer Straße 76\nBrandenburg an der Havel\n',
#   'Stadt': 'Neuendorfer Straße 76'},
#  {'Filialname': 'Netto',
#   'Straße': '\nPotsdamer Straße 16\nBrandenburg an der Havel\n',
#   'Stadt': 'Potsdamer Straße 16'},
#  {'Filialname': 'EDEKA',
#   'Straße': '\nWerner-Seelenbinder-Straße 52\nBrandenburg an der Havel\n',
#   'Stadt': 'Werner-Seelenbinder-Straße 52'},
#  {'Filialname': 'Lidl',
#   'Straße': '\nUpstallstraße 22\nBrandenburg an der Havel\n',
#   'Stadt': 'Upstallstraße 22'},
#  {'Filialname': 'EDEKA',
#   'Straße': '\nHaydnstraße 19\nBrandenburg an der Havel-Görden\n',
#   'Stadt': 'Haydnstraße 19'},
#  {'Filialname': 'REWE',
#   'Straße': '\nGenthiner Straße 43\nBrandenburg an der Havel-Plaue\n',
#   'Stadt': 'Genthiner Straße 43'},
#  {'Filialname': 'ALDI Nord',
#   'Straße': '\nWillibald-Alexis-Straße 40\nBrandenburg an der Havel-Hohenstücken\n',
#   'Stadt': 'Willibald-Alexis-Straße 40'},
#  {'Filialname': 'REWE',
# ...

# %%
from pprint import pprint
supermarkt_daten_clean = str(supermarkt_daten).replace('\\n', '')
pprint(supermarkt_daten_clean)
# Out:
# ("[{'Filialname': 'REWE', 'Straße': 'Neuendorfer Straße 76Brandenburg an der "
#  "Havel', 'Stadt': 'Neuendorfer Straße 76'}, {'Filialname': 'Netto', 'Straße': "
#  "'Potsdamer Straße 16Brandenburg an der Havel', 'Stadt': 'Potsdamer Straße "
#  "16'}, {'Filialname': 'EDEKA', 'Straße': 'Werner-Seelenbinder-Straße "
#  "52Brandenburg an der Havel', 'Stadt': 'Werner-Seelenbinder-Straße 52'}, "
#  "{'Filialname': 'Lidl', 'Straße': 'Upstallstraße 22Brandenburg an der Havel', "
#  "'Stadt': 'Upstallstraße 22'}, {'Filialname': 'EDEKA', 'Straße': 'Haydnstraße "
#  "19Brandenburg an der Havel-Görden', 'Stadt': 'Haydnstraße 19'}, "
#  "{'Filialname': 'REWE', 'Straße': 'Genthiner Straße 43Brandenburg an der "
#  "Havel-Plaue', 'Stadt': 'Genthiner Straße 43'}, {'Filialname': 'ALDI Nord', "
#  "'Straße': 'Willibald-Alexis-Straße 40Brandenburg an der Havel-Hohenstücken', "
#  "'Stadt': 'Willibald-Alexis-Straße 40'}, {'Filialname': 'REWE', 'Straße': "
# ...

# %% [markdown]
# ## Karte

# %%
import folium

supermarkt_daten = [
    {'Filialname': 'REWE', 'Straße': 'Neuendorfer Straße 76Brandenburg an der Havel', 'Stadt': 'Neuendorfer Straße 76'},
    {'Filialname': 'Netto', 'Straße': 'Potsdamer Straße 16Brandenburg an der Havel', 'Stadt': 'Potsdamer Straße 16'},
    # Füge hier die übrigen Supermarkt-Daten hinzu
]

karte = folium.Map(location=[52.4083, 12.5622], zoom_start=12)

for supermarkt in supermarkt_daten:
    filialname = supermarkt['Filialname']
    strasse = supermarkt['Straße']
    stadt = supermarkt['Stadt']

    marker = folium.Marker(location=[52.4083, 12.5622], popup=f"<b>{filialname}</b><br>{strasse}, {stadt}")

    marker.add_to(karte)

karte.save("supermarkt_karte.html")

# %%
supermarkt_daten = [{'Filialname': 'REWE', 'Straße': 'Neuendorfer Straße 76Brandenburg an der Havel', 'Stadt': 'Neuendorfer Straße 76'}, 
                    {'Filialname': 'Netto', 'Straße': 'Potsdamer Straße 16Brandenburg an der Havel', 'Stadt': 'Potsdamer Straße 16'}, 
                    {'Filialname': 'EDEKA', 'Straße': 'Werner-Seelenbinder-Straße 52Brandenburg an der Havel', 'Stadt': 'Werner-Seelenbinder-Straße 52'}, 
                    {'Filialname': 'Lidl', 'Straße': 'Upstallstraße 22Brandenburg an der Havel', 'Stadt': 'Upstallstraße 22'}, 
                    {'Filialname': 'EDEKA', 'Straße': 'Haydnstraße 19Brandenburg an der Havel-Görden', 'Stadt': 'Haydnstraße 19'}, 
                    {'Filialname': 'REWE', 'Straße': 'Genthiner Straße 43Brandenburg an der Havel-Plaue', 'Stadt': 'Genthiner Straße 43'}, 
                    {'Filialname': 'ALDI Nord', 'Straße': 'Willibald-Alexis-Straße 40Brandenburg an der Havel-Hohenstücken', 'Stadt': 'Willibald-Alexis-Straße 40'}, 
                    {'Filialname': 'REWE', 'Straße': 'Sankt-Annen-Straße 23Brandenburg an der Havel', 'Stadt': 'Sankt-Annen-Straße 23'}, 
                    {'Filialname': 'Netto', 'Straße': 'Göttiner LandstraßeBrandenburg an der Havel', 'Stadt': 'Göttiner Landstraße'}, 
                    {'Filialname': 'Netto', 'Straße': 'Willi-Sänger-Straße 46Brandenburg an der Havel', 'Stadt': 'Willi-Sänger-Straße 46'}, 
                    {'Filialname': 'ALDI Nord', 'Straße': 'Geschwister-Scholl-Straße 30Brandenburg an der Havel', 'Stadt': 'Geschwister-Scholl-Straße 30'}, 
                    {'Filialname': 'ALDI Nord', 'Straße': 'Willi-Sänger-Straße 66Brandenburg an der Havel', 'Stadt': 'Willi-Sänger-Straße 66'}, 
                    {'Filialname': 'Penny', 'Straße': 'Veilchenweg 2Brandenburg an der Havel-Görden', 'Stadt': 'Veilchenweg 2'}, 
                    {'Filialname': 'Netto', 'Straße': 'Wusterwitzer Straße 32FBrandenburg an der Havel-Kirchmöser', 'Stadt': 'Wusterwitzer Straße 32F'}, 
                    {'Filialname': 'NP-Discount', 'Straße': 'Am Neuendorfer SandBrandenburg an der Havel', 'Stadt': 'Am Neuendorfer Sand'}, 
                    {'Filialname': 'Netto', 'Straße': 'Magdeburger Landstraße 190Brandenburg an der Havel', 'Stadt': 'Magdeburger Landstraße 190'}, 
                    {'Filialname': 'REWE', 'Straße': 'Veilchenweg 2Brandenburg an der Havel-Görden', 'Stadt': 'Veilchenweg 2'}, 
                    {'Filialname': 'Netto', 'Straße': 'Rosa-Luxemburg-Allee 4ABrandenburg an der Havel-Hohenstücken', 'Stadt': 'Rosa-Luxemburg-Allee 4A'}, 
                    {'Filialname': 'Kaufland', 'Straße': 'An der Bundesstraße 1Brandenburg an der Havel-Wust', 'Stadt': 'An der Bundesstraße 1'}, 
                    {'Filialname': 'Lidl', 'Straße': 'Potsdamer Straße 23Brandenburg an der Havel', 'Stadt': 'Potsdamer Straße 23'}, 
                    {'Filialname': 'Netto', 'Straße': 'Willi-Sänger-Straße 20Brandenburg an der Havel', 'Stadt': 'Willi-Sänger-Straße 20'}, 
                    {'Filialname': 'REWE', 'Straße': 'Tschirchdamm 17Brandenburg an der Havel-Hohenstücken', 'Stadt': 'Tschirchdamm 17'}, 
                    {'Filialname': 'Lidl', 'Straße': 'Friedrich-Franz-Straße 4Brandenburg an der Havel', 'Stadt': 'Friedrich-Franz-Straße 4'}]

angepasste_supermarkt_daten = []
for supermarkt in supermarkt_daten:
    strasse_und_stadt = supermarkt['Straße'].split('Brandenburg an der Havel')
    strasse = strasse_und_stadt[0].strip()
    stadt = 'Brandenburg an der Havel'

    angepasster_supermarkt = {
        'Filialname': supermarkt['Filialname'],
        'Straße': strasse,
        'Stadt': stadt
    }

    angepasste_supermarkt_daten.append(angepasster_supermarkt)

for supermarkt in angepasste_supermarkt_daten:
    print(supermarkt)
# Out:
# {'Filialname': 'REWE', 'Straße': 'Neuendorfer Straße 76', 'Stadt': 'Brandenburg an der Havel'}
# {'Filialname': 'Netto', 'Straße': 'Potsdamer Straße 16', 'Stadt': 'Brandenburg an der Havel'}
# {'Filialname': 'EDEKA', 'Straße': 'Werner-Seelenbinder-Straße 52', 'Stadt': 'Brandenburg an der Havel'}
# {'Filialname': 'Lidl', 'Straße': 'Upstallstraße 22', 'Stadt': 'Brandenburg an der Havel'}
# {'Filialname': 'EDEKA', 'Straße': 'Haydnstraße 19', 'Stadt': 'Brandenburg an der Havel'}
# {'Filialname': 'REWE', 'Straße': 'Genthiner Straße 43', 'Stadt': 'Brandenburg an der Havel'}
# {'Filialname': 'ALDI Nord', 'Straße': 'Willibald-Alexis-Straße 40', 'Stadt': 'Brandenburg an der Havel'}
# {'Filialname': 'REWE', 'Straße': 'Sankt-Annen-Straße 23', 'Stadt': 'Brandenburg an der Havel'}
# {'Filialname': 'Netto', 'Straße': 'Göttiner Landstraße', 'Stadt': 'Brandenburg an der Havel'}
# {'Filialname': 'Netto', 'Straße': 'Willi-Sänger-Straße 46', 'Stadt': 'Brandenburg an der Havel'}
# ...

# %%
import requests

overpass_url = "http://overpass-api.de/api/interpreter"

overpass_query = """
[out:json][timeout:25];
// München als Suchbereich festlegen
area["name"="München"]->.munich;

// Supermärkte in München suchen
(
  node["shop"="supermarket"](area.munich);
  way["shop"="supermarket"](area.munich);
  relation["shop"="supermarket"](area.munich);
);
out body;
>;
out skel qt;
"""

response = requests.get(overpass_url, params={'data': overpass_query})
data = response.json()

for element in data['elements']:
    name = element.get('tags', {}).get('name', 'Unbekannt')
    owner = element.get('tags', {}).get('owner', 'Unbekannt')
    brand = element.get('tags', {}).get('brand', 'Unbekannt')
    postcode = element.get('tags', {}).get('addr:postcode', 'Unbekannt')
    city = element.get('tags', {}).get('addr:city', 'Unbekannt')
    suburb = element.get('tags', {}).get('addr:suburb', 'Unbekannt')
    street = element.get('tags', {}).get('addr:street', 'Unbekannt')
    housenumber = element.get('tags', {}).get('addr:housenumber', 'Unbekannt')
    additional = element.get('tags', {}).get('addr:additional', 'Unbekannt')

formatted_data = []
for element in data['elements']:
    name = element.get('tags', {}).get('name', 'Unbekannt')
    street = element.get('tags', {}).get('addr:street', 'Unbekannt')
    house_number = element.get('tags', {}).get('addr:housenumber', 'Unbekannt')
    city = "München" 

    formatted_data.append({
        'Filialname': name,
        'Straße': f"{street} {house_number}".strip(),
        'Stadt': city
    })

for item in formatted_data:
    print(item)
# Out:
# {'Filialname': 'EDEKA', 'Straße': 'Kreillerstraße 151', 'Stadt': 'München'}
# {'Filialname': 'EDEKA', 'Straße': 'Unbekannt Unbekannt', 'Stadt': 'München'}
# {'Filialname': 'ALDI Süd', 'Straße': 'Freisinger Landstraße 64', 'Stadt': 'München'}
# {'Filialname': 'Feneberg', 'Straße': 'Unbekannt Unbekannt', 'Stadt': 'München'}
# {'Filialname': 'VollCorner', 'Straße': 'Kaspar-Kerll-Straße 47', 'Stadt': 'München'}
# {'Filialname': 'Netto City', 'Straße': 'Hohenzollernplatz 7', 'Stadt': 'München'}
# {'Filialname': 'Kaufland', 'Straße': 'Margot-Kalinke-Straße 4', 'Stadt': 'München'}
# {'Filialname': 'ALDI Süd', 'Straße': 'Unbekannt Unbekannt', 'Stadt': 'München'}
# {'Filialname': 'Netto Marken-Discount', 'Straße': 'Schneeheideanger 4', 'Stadt': 'München'}
# {'Filialname': 'EDEKA', 'Straße': 'Schleißheimer Straße 413', 'Stadt': 'München'}
# {'Filialname': 'Netto Marken-Discount', 'Straße': 'Aschauer Straße 19', 'Stadt': 'München'}
# ...

# %%
import requests
import json

api_key = 'AIzaSyBIS3y8ziXbHXDvQGAMj_Lht2O-1jzQoS0'
url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json'

params = {
    'location': '48.137154,11.576124',  # Koordinaten von München
    'radius': '5000',  # Suchradius in Metern
    'type': 'supermarket',
    'key': api_key
}

response = requests.get(url, params=params)
data = response.json()

# Verarbeiten und Speichern der Daten
with open('supermaerkte_muenchen.json', 'w') as file:
    json.dump(data, file)

# %%
import googlemaps

# Ersetze 'DEIN_API_KEY' durch deinen tatsächlichen Google Maps API-Key
api_key = 'AIzaSyBIS3y8ziXbHXDvQGAMj_Lht2O-1jzQoS0'

# Erstelle ein Google Maps Client-Objekt mit deinem API-Key
gmaps = googlemaps.Client(key=api_key)

# Definiere den Ort (Brandenburg an der Havel)
ort = "Brandenburg an der Havel, Deutschland"

# Suche nach Supermärkten in Brandenburg an der Havel
suchbegriff = "Supermarkt in Brandenburg an der Havel"
ergebnisse = []
next_page_token = None

while True:
    if next_page_token:
        ergebnisse_seite = gmaps.places(query=suchbegriff, location=ort, radius=20000, type="supermarket", page_token=next_page_token)
    else:
        ergebnisse_seite = gmaps.places(query=suchbegriff, location=ort, radius=20000, type="supermarket")

    ergebnisse.extend(ergebnisse_seite.get('results', []))
    next_page_token = ergebnisse_seite.get('next_page_token')

    if not next_page_token:
        break

# Extrahiere und formatiere die Ergebnisse im gewünschten Format
supermarkt_daten = []

for ergebnis in ergebnisse:
    filialname = ergebnis['name']
    adresse = ergebnis.get('formatted_address', 'Adresse nicht verfügbar')  # Verwende alternative Nachricht, wenn 'vicinity' fehlt
    stadt = "Brandenburg an der Havel"
    rating = ergebnis.get('rating', 'Bewertung nicht verfügbar')  # Verwende alternative Nachricht, wenn 'rating' fehlt

    # Extrahiere die Straße aus der Adresse, falls verfügbar
    strasse = adresse.split(",")[0].strip() if "," in adresse else adresse.strip()

    supermarkt_info = {
        'Filialname': filialname,
        'Straße': strasse,
        'Stadt': stadt,
        'Rating': rating
    }

    supermarkt_daten.append(supermarkt_info)

# Drucke die Ergebnisse im gewünschten Format
for supermarkt in supermarkt_daten:
    pprint(supermarkt)
# Out:
# ---------------------------------------------------------------------------
# ApiError                                  Traceback (most recent call last)
# Cell In[5], line 19
#      17 while True:
#      18     if next_page_token:
# ---> 19         ergebnisse_seite = gmaps.places(query=suchbegriff, location=ort, radius=20000, type="supermarket", page_token=next_page_token)
#      20     else:
#      21         ergebnisse_seite = gmaps.places(query=suchbegriff, location=ort, radius=20000, type="supermarket")
#
# File c:\Users\Admin\.conda\envs\datacraft\Lib\site-packages\googlemaps\client.py:445, in make_api_method.<locals>.wrapper(*args, **kwargs)
#     442 @functools.wraps(func)
#     443 def wrapper(*args, **kwargs):
#     444     args[0]._extra_params = kwargs.pop("extra_params", None)
# --> 445     result = func(*args, **kwargs)
#     446     try:
#     447         del args[0]._extra_params
#
# ...

# %%
import requests

def get_address(lat, lng, api_key):
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"
    params = {
        "latlng": f"{lat},{lng}",
        "key": api_key
    }
    response = requests.get(base_url, params=params)
    if response.status_code == 200:
        results = response.json()['results']
        if results:
            return results[0]['formatted_address']
        else:
            return "Adresse nicht gefunden"
    else:
        return "Fehler bei der Anfrage"

# Ihr API-Schlüssel
api_key = 'AIzaSyBIS3y8ziXbHXDvQGAMj_Lht2O-1jzQoS0'

# Die Liste der Supermärkte
supermaerkte = [
      { 'Filialname': 'REWE Emil Möbus', 'lat': 52.4078484, 'lng': 12.5465674, 'rating': 4.3 },
      { 'Filialname': 'REWE', 'lat': 52.410264, 'lng': 12.546116, 'rating': 4.1 },
      { 'Filialname': 'REWE', 'lat': 52.4095724, 'lng': 12.5402324, 'rating': 4.1 },
      { 'Filialname': 'REWE Center Karen Laute', 'lat': 52.4068921, 'lng': 12.5476426, 'rating': 4.5 },
      { 'Filialname': 'mein real - Brandenburg', 'lat': 52.3964513, 'lng': 12.5485403, 'rating': 4 },
      { 'Filialname': 'Lidl', 'lat': 52.411311, 'lng': 12.548596, 'rating': 4.2 },
      { 'Filialname': 'REWE', 'lat': 52.4180132, 'lng': 12.5498497, 'rating': 4.2 },
      { 'Filialname': 'REWE', 'lat': 52.4043481, 'lng': 12.5292394, 'rating': 4.2 },
      { 'Filialname': 'Lidl', 'lat': 52.4056254, 'lng': 12.5463664, 'rating': 4.2 },
      { 'Filialname': 'Netto Marken-Discount', 'lat': 52.4039812, 'lng': 12.5588192, 'rating': 3.8 },
      { 'Filialname': 'ALDI NORD', 'lat': 52.406573, 'lng': 12.553895, 'rating': 4.1 },
      { 'Filialname': 'Lidl', 'lat': 52.416575, 'lng': 12.536145, 'rating': 4.3 },
      { 'Filialname': 'EDEKA Höppner', 'lat': 52.4035286, 'lng': 12.5486095, 'rating': 4.1 },
      { 'Filialname': 'Netto - Günstig. Besser. Für dich.', 'lat': 52.4187136, 'lng': 12.5607514, 'rating': 3.8 },
      { 'Filialname': 'EDEKA Höppner', 'lat': 52.4109649, 'lng': 12.5582829, 'rating': 3.9 },
      { 'Filialname': 'ALDI Nord', 'lat': 52.4197764, 'lng': 12.5554834, 'rating': 4 },
      { 'Filialname': 'Späti', 'lat': 52.3986893, 'lng': 12.5594066, 'rating': 4.5 },
      { 'Filialname': 'Netto - Günstig. Besser. Für dich.', 'lat': 52.3939556, 'lng': 12.5410813, 'rating': 3.9 },
      { 'Filialname': 'Netto Marken-Discount', 'lat': 52.4100866, 'lng': 12.5497681, 'rating': 3.9 },
      { 'Filialname': 'Kaufland', 'lat': 52.408523, 'lng': 12.544364, 'rating': 4.1 }]

# Aktualisieren Sie die Liste mit den Adressen
for markt in supermaerkte:
    markt['Adresse'] = get_address(markt['lat'], markt['lng'], api_key)

# Ausgabe der aktualisierten Liste
for markt in supermaerkte:
    print(markt)
# Out:
# {'Filialname': 'REWE Emil Möbus', 'lat': 52.4078484, 'lng': 12.5465674, 'rating': 4.3, 'Adresse': 'Neuendorfer Str. 76, 14770 Brandenburg an der Havel, Germany'}
# {'Filialname': 'REWE', 'lat': 52.410264, 'lng': 12.546116, 'rating': 4.1, 'Adresse': 'Vereinsstraße 13, 14770 Brandenburg an der Havel, Germany'}
# {'Filialname': 'REWE', 'lat': 52.4095724, 'lng': 12.5402324, 'rating': 4.1, 'Adresse': 'Vereinsstraße 36, 14770 Brandenburg an der Havel, Germany'}
# {'Filialname': 'REWE Center Karen Laute', 'lat': 52.4068921, 'lng': 12.5476426, 'rating': 4.5, 'Adresse': 'Neuendorfer Str. 77b, 14770 Brandenburg an der Havel, Germany'}
# {'Filialname': 'mein real - Brandenburg', 'lat': 52.3964513, 'lng': 12.5485403, 'rating': 4, 'Adresse': 'Wilhelmsdorfer Str. 42A, 14776 Brandenburg an der Havel, Germany'}
# {'Filialname': 'Lidl', 'lat': 52.411311, 'lng': 12.548596, 'rating': 4.2, 'Adresse': 'Nicolaipl. 10, 14770 Brandenburg an der Havel, Germany'}
# ...

# %%
    var supermärkte = [
      { name: 'REWE Emil Möbus', lat: 52.4078484, lng: 12.5465674, rating: 4.3 },
      { name: 'REWE', lat: 52.410264, lng: 12.546116, rating: 4.1 },
      { name: 'REWE', lat: 52.4095724, lng: 12.5402324, rating: 4.1 },
      { name: 'REWE Center Karen Laute', lat: 52.4068921, lng: 12.5476426, rating: 4.5 },
      { name: 'mein real - Brandenburg', lat: 52.3964513, lng: 12.5485403, rating: 4 },
      { name: 'Lidl', lat: 52.411311, lng: 12.548596, rating: 4.2 },
      { name: 'REWE', lat: 52.4180132, lng: 12.5498497, rating: 4.2 },
      { name: 'REWE', lat: 52.4043481, lng: 12.5292394, rating: 4.2 },
      { name: 'Lidl', lat: 52.4056254, lng: 12.5463664, rating: 4.2 },
      { name: 'Netto Marken-Discount', lat: 52.4039812, lng: 12.5588192, rating: 3.8 },
      { name: 'ALDI NORD', lat: 52.406573, lng: 12.553895, rating: 4.1 },
      { name: 'Lidl', lat: 52.416575, lng: 12.536145, rating: 4.3 },
      { name: 'EDEKA Höppner', lat: 52.4035286, lng: 12.5486095, rating: 4.1 },
      { name: 'Netto - Günstig. Besser. Für dich.', lat: 52.4187136, lng: 12.5607514, rating: 3.8 },
      { name: 'EDEKA Höppner', lat: 52.4109649, lng: 12.5582829, rating: 3.9 },
      { name: 'ALDI Nord', lat: 52.4197764, lng: 12.5554834, rating: 4 },
      { name: 'Späti', lat: 52.3986893, lng: 12.5594066, rating: 4.5 },
      { name: 'Netto - Günstig. Besser. Für dich.', lat: 52.3939556, lng: 12.5410813, rating: 3.9 },
      { name: 'Netto Marken-Discount', lat: 52.4100866, lng: 12.5497681, rating: 3.9 },
      { name: 'Kaufland', lat: 52.408523, lng: 12.544364, rating: 4.1 }
    ];

# %%
        <div class="row mt-4">
            <div class="col-md-4 mb-4">
                <div class="card">
                    <div class="card-body">
                        <h5 class="card-title">REWE Emil Möbus</h5>
                        <p class="card-text">Adresse: Neuendorfer Str. 76, 14770 Brandenburg an der Havel, Germany</p>
                        <p class="card-text"><strong>Bewertung: 4.3</strong></p>
                    </div>
                </div>
            </div>
            
            <div class="col-md-4 mb-4">
                <div class="card">
                    <div class="card-body">
                        <h5 class="card-title">REWE</h5>
                        <p class="card-text">Adresse: Vereinsstraße 13, 14770 Brandenburg an der Havel, Germany</p>
                        <p class="card-text"><strong>Bewertung: 4.1</strong></p>
                    </div>
                </div>
            </div>
            
            <div class="col-md-4 mb-4">
                <div class="card">
                    <div class="card-body">
                        <h5 class="card-title">REWE</h5>
                        <p class="card-text">Adresse: Vereinsstraße 36, 14770 Brandenburg an der Havel, Germany</p>
                        <p class="card-text"><strong>Bewertung: 4.1</strong></p>
                    </div>
                </div>
            </div>
            
            <div class="col-md-4 mb-4">
                <div class="card">
                    <div class="card-body">
                        <h5 class="card-title">REWE Center Karen Laute</h5>
                        <p class="card-text">Adresse: Neuendorfer Str. 77b, 14770 Brandenburg an der Havel, Germany</p>
                        <p class="card-text"><strong>Bewertung: 4.5</strong></p>
                    </div>
                </div>
            </div>
            
            <div class="col-md-4 mb-4">
                <div class="card">
                    <div class="card-body">
                        <h5 class="card-title">REWE Emil Möbus</h5>
                        <p class="card-text">Adresse: Neuendorfer Str. 76, 14770 Brandenburg an der Havel, Germany</p>
                        <p class="card-text"><strong>Bewertung: 4.3</strong></p>
                    </div>
                </div>
            </div>
            
            <div class="col-md-4 mb-4">
                <div class="card">
                    <div class="card-body">
                        <h5 class="card-title">REWE</h5>
                        <p class="card-text">Adresse: Vereinsstraße 13, 14770 Brandenburg an der Havel, Germany</p>
                        <p class="card-text"><strong>Bewertung: 4.1</strong></p>
                    </div>
                </div>
            </div>
            
            <div class="col-md-4 mb-4">
                <div class="card">
                    <div class="card-body">
                        <h5 class="card-title">Lidl</h5>
                        <p class="card-text">Adresse: Nicolaipl. 10, 14770 Brandenburg an der Havel, Germany</p>
                        <p class="card-text"><strong>Bewertung: 4.2</strong></p>
                    </div>
                </div>
            </div>
            
            <div class="col-md-4 mb-4">
                <div class="card">
                    <div class="card-body">
                        <h5 class="card-title">REWE</h5>
                        <p class="card-text">Adresse: Willi-Sänger-Straße 17, 14770 Brandenburg an der Havel, Germany</p>
                        <p class="card-text"><strong>Bewertung: 4.2</strong></p>
                    </div>
                </div>
            </div>

            <div class="col-md-4 mb-4">
                <div class="card">
                    <div class="card-body">
                        <h5 class="card-title">REWE</h5>
                        <p class="card-text">Adresse: Caasmannstraße 7, 14770 Brandenburg an der Havel, Germany</p>
                        <p class="card-text"><strong>Bewertung: 4.2</strong></p>
                    </div>
                </div>
            </div>
            
            <div class="col-md-4 mb-4">
                <div class="card">
                    <div class="card-body">
                        <h5 class="card-title">Lidl</h5>
                        <p class="card-text">Adresse: Franz-Ziegler-Straße 28, 14776 Brandenburg an der Havel, Germany</p>
                        <p class="card-text"><strong>Bewertung: 4.2</strong></p>
                    </div>
                </div>
            </div>
            
            <div class="col-md-4 mb-4">
                <div class="card">
                    <div class="card-body">
                        <h5 class="card-title">NETTO Marken-Discount</h5>
                        <p class="card-text">Adresse: Trauerberg 1B, 14776 Brandenburg an der Havel, Germany</p>
                        <p class="card-text"><strong>Bewertung: 4.3</strong></p>
                    </div>
                </div>
            </div>
            
            <div class="col-md-4 mb-4">
                <div class="card">
                    <div class="card-body">
                        <h5 class="card-title">Aldi Nord</h5>
                        <p class="card-text">Adresse: Am Mühlengraben 22, 14776 Brandenburg an der Havel, Germany</p>
                        <p class="card-text"><strong>Bewertung: 4.1</strong></p>
                    </div>
                </div>
            </div>
            
            <div class="col-md-4 mb-4">
                <div class="card">
                    <div class="card-body">
                        <h5 class="card-title">Lidl</h5>
                        <p class="card-text">Adresse: Neuendorfer Str. 76, 14770 Brandenburg an der Havel, Germany</p>
                        <p class="card-text"><strong>Bewertung: 4.3</strong></p>
                    </div>
                </div>
            </div>
            
            <div class="col-md-4 mb-4">
                <div class="card">
                    <div class="card-body">
                        <h5 class="card-title">EDEKA Höppner</h5>
                        <p class="card-text">Adresse: Vereinsstraße 13, 14770 Brandenburg an der Havel, Germany</p>
                        <p class="card-text"><strong>Bewertung: 4.1</strong></p>
                    </div>
                </div>
            </div>
            
            <div class="col-md-4 mb-4">
                <div class="card">
                    <div class="card-body">
                        <h5 class="card-title">NETTO Marken-Discount</h5>
                        <p class="card-text">Adresse: Beetzseeufer 4, 14770 Brandenburg an der Havel, Germany</p>
                        <p class="card-text"><strong>Bewertung: 3.8</strong></p>
                    </div>
                </div>
            </div>
            
            <div class="col-md-4 mb-4">
                <div class="card">
                    <div class="card-body">
                        <h5 class="card-title">EDEKA Höppner</h5>
                        <p class="card-text">Adresse: Hauptstraße 51, 14776 Brandenburg an der Havel, Germany</p>
                        <p class="card-text"><strong>Bewertung: 3.9</strong></p>
                    </div>
                </div>
            </div>
            
            <div class="col-md-4 mb-4">
                <div class="card">
                    <div class="card-body">
                        <h5 class="card-title">ALDI Nord</h5>
                        <p class="card-text">Adresse: Brielower Str. 15b, 14770 Brandenburg an der Havel, Germany</p>
                        <p class="card-text"><strong>Bewertung: 4.0</strong></p>
                    </div>
                </div>
            </div>
            
            <div class="col-md-4 mb-4">
                <div class="card">
                    <div class="card-body">
                        <h5 class="card-title">NETTO Marken-Discount</h5>
                        <p class="card-text">Adresse: Wilhelmsdorfer Landstraße 41, 14776 Brandenburg an der Havel, Germany</p>
                        <p class="card-text"><strong>Bewertung: 3.9</strong></p>
                    </div>
                </div>
            </div>
            
            <div class="col-md-4 mb-4">
                <div class="card">
                    <div class="card-body">
                        <h5 class="card-title">NETTO Marken-Discount</h5>
                        <p class="card-text">Adresse: Neuendorfer Str. 76, 14770 Brandenburg an der Havel, Germany</p>
                        <p class="card-text"><strong>Bewertung: 3.9</strong></p>
                    </div>
                </div>
            </div>
            
            <div class="col-md-4 mb-4">
                <div class="card">
                    <div class="card-body">
                        <h5 class="card-title">Kaufland</h5>
                        <p class="card-text">Adresse: Damaschkestraße 31, 14770 Brandenburg an der Havel, Germany</p>
                        <p class="card-text"><strong>Bewertung: 4.1</strong></p>
                    </div>
                </div>
            </div>
